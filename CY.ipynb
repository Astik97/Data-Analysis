# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fd = pd.read_csv('Corn_Yield.csv')

# %%
X=fd.iloc[:,:-1].values
Y=fd.iloc[:,-1].values

# %%
from sklearn.linear_model import LinearRegression
lin_reg=LinearRegression()
lin_reg.fit(X,Y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures
pf=PolynomialFeatures(degree=2)
X_plot=pf.fit_transform(X)
poly_reg=LinearRegression()
poly_reg.fit(X_plot,Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X,Y,color='red')
plt.plot(X,lin_reg.predict(X),color='blue')
plt.title("Yield vs Fertilizer")
plt.xlabel("Fertilizer")
plt.ylabel("Yield")
plt.show()

# %%
fertilizer=input("Enter the value of fertilizer:")
fert=float(fertilizer)
# Out:
# Enter the value of fertilizer: 50.16

# %%
lin_reg.predict([[50.16]])
# Out:
# array([196.55195841])

# %%
poly_reg.predict(pf.fit_transform([[50.16]]))
# Out:
# array([150.62470196])
