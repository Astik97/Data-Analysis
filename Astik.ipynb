# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("A:\Dataset\Successful_Startups.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\astik\AppData\Local\Temp\ipykernel_22336\217471966.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("A:\Dataset\Successful_Startups.csv")

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend   Season     Profit
# 0   165349.20       136897.80        471784.10  Season1  192261.83
# 1   162597.70       151377.59        443898.53  Season2  191792.06
# 2   153441.51       101145.55        407934.54  Season3  191050.39
# 3   144372.41       118671.85        383199.62  Season1  182901.99
# 4   142107.34        91391.77        366168.42  Season3  166187.94
# 5   131876.90        99814.71        362861.36  Season1  156991.12
# 6   134615.46       147198.87        127716.82  Season2  156122.51
# 7   130298.13       145530.06        323876.68  Season3  155752.60
# 8   120542.52       148718.95        311613.29  Season1  152211.77
# 9   123334.88       108679.17        304981.62  Season2  149759.96
# 10  101913.08       110594.11        229160.95  Season3  146121.95
# 11  100671.96        91790.61        249744.55  Season2  144259.40
# 12   93863.75       127320.38        249839.44  Season3  141585.52
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   Season           50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.drop(['Season'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
pd.isnull(df).sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# Profit             0
# dtype: int64

# %%
df.shape
# Out:
# (50, 4)

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'Profit'], dtype='object')

# %%
evaluate=df.groupby(['R&D Spend'],as_index=False)['Administration'].sum().sort_values(by='R&D Spend',ascending=False).head(15)
sns.set(rc={'figure.figsize':(50,10)})
sns.barplot(data = evaluate,x='R&D Spend',y='Administration')
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Administration'>

# %%
sns.barplot(x='Marketing Spend',y='Profit',data=df)
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>

# %%
sns.scatterplot(x='R&D Spend',y='Administration',data=df)
# Out:
# <Axes: xlabel='R&D Spend', ylabel='Administration'>

# %%
sns.scatterplot(x='Marketing Spend',y='Profit',data=df)
# Out:
# <Axes: xlabel='Marketing Spend', ylabel='Profit'>

# %% [markdown]
# As per the R&D Spend at 75000,the administration is at maximized and in other points of R&D Spend yhe administration is minimized.

# %% [markdown]
# As per the graph b/w Marketing Spend and Profit is shown that the Profit is increased by the increasing value of Marketing Spend.
# Similarly,in decreasing case of values it is same as the increasing case.
